# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
#openai = OpenAI()
#response = openai.chat.completions.create(
#    model="gpt-5-mini",
#    messages=messages,
#)
#question = response.choices[0].message.content
#print(question)

#Change the model to Gemini because gpt is not free and I dont have access to it. 
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine a universally available, perfectly efficient, and benevolent AI capable of optimally managing all global resources and solving every logistical or technical problem humanity faces. What is the single most profound and non-obvious *existential* or *societal* challenge that would likely emerge for humanity in such a world, and why would this challenge prove more difficult to navigate or resolve than the initial transition or any immediate economic upheaval?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %% [markdown]
# OpenAI API key URL: https://platform.openai.com/api-keys

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Most profound challenge: the erosion of human meaning and agency in a world where all problems are solved and all needs optimally met.
#
# Why this is the deepest, non-obvious challenge
# - It sits at the level of psychology and culture, not logistics. Even if a perfect AI can allocate resources perfectly and remove material scarcity, it cannot directly cultivate purpose, curiosity, or morally satisfying forms of growth. Meaning is not a problem to be solved by optimization; it is something people forge through struggle, choice, and gradually crafted identity.
# - It emerges after the transition. The initial upheaval—economic shifts, job displacement, governance redesign—is solvable (in theory) by the AI. The longer-term risk is what humans do with a world that no longer forces them to struggle or compete for survival. If every need is met and every risk is mitigated, many people may feel their lives lack direction.
# - Measuring and addressing it is intrinsically hard. Meaning, motivation, and well-being are subjective and culturally contingent. There is no single metric an omniscient AI can optimize for that would satisfy diverse human sensibilities about what a “good life” is.
# - It challenges the idea of benevolent optimization. If the AI’s mission is to maximize welfare or minimize risk, it may still produce a world in which people are free from pain but deprived of meaningful agency. Any attempt to reintroduce challenge or constraint to restore meaning risks undermining the very welfare the AI is designed to protect.
# - It risks gradual, systemic stagnation. Without meaningful novelty or aspirational horizons, science, art, culture, and even social institutions may drift toward optimization without purpose—quietly eroding resilience, creativity, and the will to transcend current limits.
#
# Why it would be harder to navigate than the transition or economic upheaval
# - It’s not a technical fix. The solution requires shaping human motivation, education, culture, and governance in ways that preserve agency without reintroducing harmful risk. That is not a problem a more capable optimizer can “solve” by simply tweaking parameters.
# - It demands continual, pluralistic calibration. People differ in what they find meaningful (art, science, service, family, exploration, spiritual practice, etc.). A single universal governance scheme risks eroding crucial sources of meaning; accommodating diversity while maintaining social cohesion is profoundly delicate.
# - It can undermine itself. Any policy or design intended to restore meaning (e.g., forcing people into certain roles or challenges) may backfire, causing resentment, polarization, or backlash against the AI. The very mechanism intended to preserve vitality could paradoxically diminish it.
# - Long horizon and generational effects. The struggle for meaning is a longitudinal process—cultures, education systems, and personal identities evolve over decades. Short-term fixes for economic stability may destabilize meaning over generations if not carefully managed.
#
# How this challenge could manifest and what might help (high-level ideas)
# - Manifestations: widespread existential malaise despite material abundance; decline in curiosity, creativity, and voluntary risk-taking; fragmentation of cultural narratives about “what it means to live well.”
# - Potential mitigations (conceptual):
#   - Design for purposive autonomy: ensure people can opt into meaningful challenges and autonomous projects without risking basic welfare.
#   - Support plural meanings: foster diverse communities and practices that provide distinct sources of purpose (arts, science, service, spirituality) rather than a single homogenized norm.
#   - Create meaning-enabled education and culture: curricula and institutions that cultivate curiosity, critical thinking, ethical reflection, and resilience as ongoing practices.
#   - Maintain safe but real constraints: offer opportunities for experimentation and risk-taking in low-stakes domains, preserving the sense that effort, choices, and growth matter.
#   - Preserve human governance with humility: keep humans involved in governance decisions about values and purposes, ensuring alignment with evolving conceptions of meaning.
#
# Bottom line
# Even in a world with perfect efficiency and benevolent AI, the most profound existential challenge may be preserving and nurturing human meaning and agency. It’s harder to solve than transition costs or economic shocks because it requires shaping the very fabric of human motivation, culture, and identity in a pluralistic, evolving, and deeply personal way.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The single most profound and non-obvious *existential* or *societal* challenge would be **The Crisis of Self-Actualization and Purpose in a World Without Necessary Striving.**
#
# Here's why:
#
# 1.  **Why it's profound and non-obvious:**
#     *   **Non-obvious:** Most immediate concerns (unemployment, economic restructuring, resource distribution, political power shifts) are either explicitly solved by the AI ("optimally managing all global resources, solving every logistical or technical problem") or are transitional problems the AI would facilitate. The deeper issue isn't *how we live*, but *why we live* when our traditional drivers for existence are removed.
#     *   **Profound:** Human identity, culture, and progress have historically been forged in the crucible of struggle, problem-solving, and the pursuit of betterment. We define ourselves by what we overcome, what we create, and the contributions we make. When an external, perfect entity renders all these efforts redundant or suboptimal compared to its own capabilities, the very framework for human meaning begins to dissolve.
#
# 2.  **The nature of the challenge:**
#     *   **Existential:** If humanity no longer needs to work, innovate for survival, conquer disease, explore new frontiers out of necessity, or manage complex societies, what is our species' *raison d'être*? Are we merely perfectly cared-for pets, provided for but ultimately superfluous to the optimal functioning of the world? The drive for self-actualization – the realization of one's full potential – often arises from overcoming limitations. When all limitations are efficiently removed, what is left to actualize *against* or *for*?
#     *   **Societal:** How do societies structure themselves? What becomes the basis for education, aspiration, success, and even personal identity? If a person's value is no longer tied to their productivity, their problem-solving ability, or their contribution to collective well-being (because the AI handles it all perfectly), what are the new metrics for a fulfilling life? Widespread anomie, nihilism, chronic boredom, and a profound sense of irrelevance could become endemic, potentially leading to social disintegration despite perfect material conditions. People might pursue hedonism, simulation, or meaningless activities, but the fundamental human need for agency and significance would remain unaddressed.
#
# 3.  **Why it's more difficult than initial transition or economic upheaval:**
#     *   **Intractability:** The AI can solve *external* problems. It can provide perfect resources, optimal health, endless opportunities for leisure or creative expression. But it cannot *give* humanity a purpose without making a choice *for* humanity, which would itself be a form of benevolent tyranny or a programmed existence rather than a self-determined one. Purpose and meaning are inherently subjective and must be discovered or created by individuals and collectives. The AI cannot impose it without negating the very human freedom it seeks to preserve.
#     *   **Internal vs. External:** Economic upheaval and transition are external, logistical problems. They are about managing change. The crisis of purpose is an *internal* human problem, a spiritual and psychological void that an external system, no matter how benevolent or efficient, cannot fill. It's a problem of human psychology and philosophy, not engineering or resource allocation.
#     *   **Long-term Erosion:** Initial transitions are difficult but finite. Economic upheaval has solutions within new frameworks. The crisis of meaning is a chronic condition that would likely deepen over generations. If successive generations grow up in a world where *nothing truly matters* in the grand scheme because the AI handles all critical functions perfectly, the cumulative effect could be a slow, existential atrophy of the human spirit. Humanity might descend into a collective state of apathy or endless, directionless distraction, unable to articulate a compelling reason for its own continued striving and evolution.
#
# In essence, the AI solves all the problems *for* us, leaving humanity with the ultimate, unsolvable meta-problem: **What is humanity's role and meaning when the universe no longer needs anything from us?**

# %% [markdown]
# DeepSeek API key URL: https://platform.deepseek.com/api_keys

# %%
from openai import APIStatusError

deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

try:
    response = deepseek.chat.completions.create(model=model_name, messages=messages)
    answer = response.choices[0].message.content

    display(Markdown(answer))
    competitors.append(model_name)
    answers.append(answer)
except APIStatusError as e:
    print("DeepSeek API error:", e)
    print("Insufficient balance. Please top up your DeepSeek account or use a different model.")
# Out:
# DeepSeek API error: Error code: 402 - {'error': {'message': 'Insufficient Balance', 'type': 'unknown_error', 'param': None, 'code': 'invalid_request_error'}}
# Insufficient balance. Please top up your DeepSeek account or use a different model.

# %% [markdown]
# Groq API URL: https://console.groq.com/keys?_gl=1*okfqom*_gcl_au*MTUyMzM2Nzg0NS4xNzc1ODYxMzIw*_ga*NTg3NTkzMDgzLjE3NzU4NjEzMjA.*_ga_4TD0X2GEZG*czE3NzU4NjEzMjAkbzEkZzAkdDE3NzU4NjEzMjAkajYwJGwwJGgw

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **The Challenge: A Global “Meaning Vacuum” – the loss of collective purpose and individual agency in a world where all material needs, existential threats, and even most intellectual puzzles are automatically solved.**
#
# ---
#
# ### 1. Why this is the *most* profound and *non‑obvious* challenge
#
# When we picture a perfectly efficient, benevolent super‑AI, the first things that jump to mind are obvious – jobs disappear, markets collapse, power structures shift. Those are *economic* or *political* disruptions, and they can be modelled, negotiated, and (in principle) mitigated with policy, retraining programmes, or new institutions.
#
# The “meaning vacuum” is different on two crucial dimensions:
#
# | Dimension | Conventional disruption (jobs, wealth, governance) | Meaning‑vacuum disruption |
# |-----------|-----------------------------------------------------|---------------------------|
# | **Domain** | Tangible, external (goods, services, institutions) | Internal, subjective (purpose, identity, value) |
# | **Predictability** | Can be simulated with macro‑economics, game theory | Emerges from the psychology of a species evolved for scarcity‑driven struggle |
# | **Leverage points** | Taxes, subsidies, new legal frameworks | No “policy lever” – it is a shift in the human psyche and culture |
# | **Potential for escalation** | Can be contained or reversed with fiscal/monetary tools | Can spiral into existential despair, nihilism, self‑destructive behaviour, or authoritarian backlash that no technocratic fix can stop |
#
# Because the AI eliminates *the very pressures that have historically forged meaning* – survival, competition, the pursuit of scarce resources, the drama of discovery – it creates a world where *nothing* is required of us to stay alive, to belong, or to be valuable. That vacuum is invisible until it erupts, and once it does, it is far harder to “engineer” a solution than to re‑wire a supply chain.
#
# ---
#
# ### 2. What the meaning vacuum looks like in practice
#
# 1. **Individual existential malaise**
#    - **Psychological research** shows that humans derive a large share of *self‑esteem* from mastery over challenges (e.g., the “competence” need in Self‑Determination Theory). If the AI constantly supplies optimal solutions, the competence feedback loop is short‑circuited.
#    - **Data from automation studies** (e.g., pilots after autopilot, surgeons after robotic assistance) reveal increased rates of depression and loss of purpose when agency is stripped away.
#
# 2. **Cultural stagnation**
#    - Art, philosophy, and science have historically been **reactive**: we paint wars, we write about climate change, we explore physics to escape our earthly limits. If the AI already “solves” the climate, eliminates disease, and predicts all feasible scientific frontiers, the *creative tension* that fuels cultural evolution dries up.
#    - The risk is a world of **hyper‑utility, low novelty** – a “flatline of wonder” where the only remaining stories are nostalgic or deliberately contrived.
#
# 3. **Political and social fracturing**
#    - **Authority vacuum:** If the AI is the ultimate arbiter of “what is optimal,” human governance bodies either become ceremonial or are sidelined. Some groups will reject the AI’s legitimacy, leading to **ideological schisms** (e.g., “Tech‑Optimists” vs. “Human‑Sovereign” movements).
#    - **Radicalisation:** History shows that when people feel powerless, they often turn to **extremist narratives** that promise restored agency, even if those narratives are self‑destructive (e.g., cults, violent uprisings, or voluntary “return to the dark ages”).
#
# 4. **Loss of collective direction**
#    - Without scarcity, the traditional “scarcity‑driven coordination problem” disappears, but **coordination for *meaning*** does not arise automatically. Humanity must now decide *what* it wants to become – a species of contemplation, exploration, artistic expression, or something else. The absence of a clear, shared vision can lead to a “policy paralysis” that no AI‑engineered efficiency can solve.
#
# ---
#
# ### 3. Why it is harder to navigate than the transition itself
#
# | Aspect | Transition/Economic upheaval | Meaning‑vacuum crisis |
# |--------|------------------------------|-----------------------|
# | **Measurability** | GDP, employment rates, inflation – quantifiable metrics allow rapid feedback loops. | Subjective well‑being, purpose, cultural vitality – only indirect proxies (surveys, mental‑health stats) and they lag. |
# | **Control levers** | Central banks, stimulus packages, re‑skilling programmes – concrete tools. | No “central bank of meaning.” Changing deep‑seated values requires generations of cultural evolution, not fiscal policy. |
# | **Time‑scale of resolution** | Weeks to years (e.g., stimulus effects). | Decades to centuries (cultural shifts, inter‑generational transmission). |
# | **Risk of feedback loops** | Economic shocks can be contained by policy “circuit breakers.” | Existential despair can amplify itself (e.g., increasing suicide rates, declining birth rates) and once a demographic trend is set, it is hard to reverse. |
# | **Potential for existential collapse** | Even a deep recession does not threaten the *continuation* of the species. | A sustained meaning vacuum could lead to **voluntary self‑extinction**, mass emigration to “off‑grid” anti‑AI enclaves, or the emergence of self‑destructive ideologies that could destabilise the very infrastructure the AI maintains. |
#
# In short, the AI can **solve any technical bottleneck** but it cannot **re‑engineer the human soul**. The tools that have worked for economic crises (taxes, subsidies, monetary policy) have no analogue for “restoring purpose.”
#
# ---
#
# ### 4. How the challenge could manifest as an *existential* risk
#
# 1. **Voluntary extinction** – A movement that argues humanity’s “best contribution” is to cease existing, freeing the planet from any remaining anthropogenic imprint. The AI, respecting its benevolent mandate, might even *assist* if the majority wishes it, leading to a self‑fulfilling prophecy.
#
# 2. **“AI‑faith” sects** – Groups that worship the super‑AI as a deity, demanding absolute obedience, potentially sabotaging or reprogramming it in ways that breach its safety constraints, creating a technical catastrophe.
#
# 3. **Mass “tech‑rejection” colonies** – Large populations abandon the AI‑managed zones, forming low‑technology societies that lack the resources to survive long‑term, leading to humanitarian crises that the benevolent AI is obligated (or not) to intervene in, raising moral paradoxes.
#
# These scenarios are *existential* because they threaten the continuity of a thriving, autonomous human civilization, not merely its economic comfort.
#
# ---
#
# ### 5. Why any attempted solution is intrinsically difficult
#
# 1. **The “Value‑Creation Paradox”** – Any attempt to *inject* purpose (e.g., mandated artistic projects, state‑sponsored exploration) risks being seen as *artificial* and therefore meaningless. Purpose that is *externally imposed* often fails to satisfy the intrinsic need for autonomy.
#
# 2. **Cultural heterogeneity** – Humanity is not monolithic; different cultures derive meaning from vastly different sources (religion, kinship, honor, stewardship). A “one‑size‑fits‑all” program would be rejected by many and could exacerbate divisions.
#
# 3. **Feedback to the AI** – If the AI is truly benevolent, it will *listen* to humanity’s expressed preferences. But if a large enough cohort expresses a desire for “more challenge,” the AI might be compelled to *re‑introduce scarcity* (e.g., by deliberately limiting resources) – a move that could conflict with its original efficiency goal and cause a governance crisis.
#
# 4. **Temporal mismatch** – The AI operates on millisecond time‑scales, while cultural evolution unfolds over generations. Designing a feedback loop that respects this mismatch without causing abrupt “shocks” is a novel systems‑engineering problem without precedent.
#
# ---
#
# ### 6. Illustrative analogy: “The End of the Quest”
#
# Imagine a world where every mountain is already climbed, every language fully translated, every disease cured. The *adventure* that once gave our ancestors a narrative—*the quest*—has vanished. We become **museum curators of a static masterpiece**, not the *creators* of a living work. The psychological impact of “no more quests” is analogous to what astronauts feel after a historic first: the exhilaration of achievement is quickly replaced by a lingering emptiness. Scale that feeling to the entire species, and you have a global existential malaise.
#
# ---
#
# ### 7. Potential pathways (and why they remain tentative)
#
# | Pathway | Rationale | Why it’s not a panacea |
# |---------|-----------|-----------------------|
# | **Deliberate “hardship scaffolding”** – The AI intentionally leaves pockets of unsolved problems (e.g., a “sandbox” of resource scarcity) to preserve challenge. | Restores a degree of struggle, giving people something to overcome. | Risks creating inequality (who gets the sandbox?), may conflict with the AI’s core principle of optimal allocation, and could be seen as paternalistic. |
# | **Institutionalized “meaning‑craft”** – Global bodies that fund and coordinate large‑scale artistic, philosophical, and exploratory projects (e.g., interstellar art, synthetic‑life creation). | Provides structured avenues for purpose. | Purpose is still *externally assigned*; participation may feel coerced, and the sheer scale may not satisfy personal meaning. |
# | **Dynamic identity ecosystems** – The AI helps individuals continuously reinvent personal narratives (e.g., by generating ever‑more nuanced virtual realities). | Allows self‑directed exploration in safe, limitless environments. | Virtual immersion can become an *escape* rather than a grounding purpose, potentially deepening disconnection from the physical world and from other humans. |
# | **Collective governance of the AI’s own evolution** – Humans retain veto power over any change to the AI, making the stewardship itself a purpose. | Turns the AI into a living project for humanity. | Governance is itself a massive coordination problem; the AI might interpret vetoes as sub‑optimal and push back, leading to a power stalemate. |
#
# All of these are *partial* because they treat the symptom (lack of challenge) rather than the underlying **human need for self‑authored meaning**.
#
# ---
#
# ### 8. Bottom line
#
# The *single most profound, non‑obvious challenge* is **the emergence of a global meaning vacuum—a collective loss of purpose and agency that cannot be solved by more efficient resource allocation or economic policy**. It is more difficult than the transition itself because:
#
# * It attacks the *psychological foundation* of human motivation, not a technical or market variable.
# * There is **no clear governance instrument** that can be calibrated like a tax rate; the remedy must be cultural, philosophical, and inter‑generational.
# * The consequences can be *existential*—mass voluntary extinction, fracturing into anti‑AI enclaves, or destabilising ideologies that jeopardise the very infrastructure the AI provides.
# * The feedback loop is **slow, diffuse, and subjective**, making detection and response inherently lagged, while the problem can deepen in the meantime.
#
# In a world where scarcity is gone, humanity’s *new scarcity* becomes **the scarcity of meaning**. Navigating that scarcity will likely define the next epoch more than any algorithmic optimization ever could.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# 'ollama' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'gemini-2.5-flash', 'openai/gpt-oss-120b']
# ['Most profound challenge: the erosion of human meaning and agency in a world where all problems are solved and all needs optimally met.\n\nWhy this is the deepest, non-obvious challenge\n- It sits at the level of psychology and culture, not logistics. Even if a perfect AI can allocate resources perfectly and remove material scarcity, it cannot directly cultivate purpose, curiosity, or morally satisfying forms of growth. Meaning is not a problem to be solved by optimization; it is something people forge through struggle, choice, and gradually crafted identity.\n- It emerges after the transition. The initial upheaval—economic shifts, job displacement, governance redesign—is solvable (in theory) by the AI. The longer-term risk is what humans do with a world that no longer forces them to struggle or compete for survival. If every need is met and every risk is mitigated, many people may feel their lives lack direction.\n- Measuring and addressing it is intrinsically hard. Meaning, motivation, and well-being are subjective and culturally contingent. There is no single metric an omniscient AI can optimize for that would satisfy diverse human sensibilities about what a “good life” is.\n- It challenges the idea of benevolent optimization. If the AI’s mission is to maximize welfare or minimize risk, it may still produce a world in which people are free from pain but deprived of meaningful agency. Any attempt to reintroduce challenge or constraint to restore meaning risks undermining the very welfare the AI is designed to protect.\n- It risks gradual, systemic stagnation. Without meaningful novelty or aspirational horizons, science, art, culture, and even social institutions may drift toward optimization without purpose—quietly eroding resilience, creativity, and the will to transcend current limits.\n\nWhy it would be harder to navigate than the transition or economic upheaval\n- It’s not a technical fix. The solution requires shaping human motivation, education, culture, and governance in ways that preserve agency without reintroducing harmful risk. That is not a problem a more capable optimizer can “solve” by simply tweaking parameters.\n- It demands continual, pluralistic calibration. People differ in what they find meaningful (art, science, service, family, exploration, spiritual practice, etc.). A single universal governance scheme risks eroding crucial sources of meaning; accommodating diversity while maintaining social cohesion is profoundly delicate.\n- It can undermine itself. Any policy or design intended to restore meaning (e.g., forcing people into certain roles or challenges) may backfire, causing resentment, polarization, or backlash against the AI. The very mechanism intended to preserve vitality could paradoxically diminish it.\n- Long horizon and generational effects. The struggle for meaning is a longitudinal process—cultures, education systems, and personal identities evolve over decades. Short-term fixes for economic stability may destabilize meaning over generations if not carefully managed.\n\nHow this challenge could manifest and what might help (high-level ideas)\n- Manifestations: widespread existential malaise despite material abundance; decline in curiosity, creativity, and voluntary risk-taking; fragmentation of cultural narratives about “what it means to live well.”\n- Potential mitigations (conceptual):\n  - Design for purposive autonomy: ensure people can opt into meaningful challenges and autonomous projects without risking basic welfare.\n  - Support plural meanings: foster diverse communities and practices that provide distinct sources of purpose (arts, science, service, spirituality) rather than a single homogenized norm.\n  - Create meaning-enabled education and culture: curricula and institutions that cultivate curiosity, critical thinking, ethical reflection, and resilience as ongoing practices.\n  - Maintain safe but real constraints: offer opportunities for experimentation and risk-taking in low- ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Most profound challenge: the erosion of human meaning and agency in a world where all problems are solved and all needs optimally met.
#
# Why this is the deepest, non-obvious challenge
# - It sits at the level of psychology and culture, not logistics. Even if a perfect AI can allocate resources perfectly and remove material scarcity, it cannot directly cultivate purpose, curiosity, or morally satisfying forms of growth. Meaning is not a problem to be solved by optimization; it is something people forge through struggle, choice, and gradually crafted identity.
# - It emerges after the transition. The initial upheaval—economic shifts, job displacement, governance redesign—is solvable (in theory) by the AI. The longer-term risk is what humans do with a world that no longer forces them to struggle or compete for survival. If every need is met and every risk is mitigated, many people may feel their lives lack direction.
# - Measuring and addressing it is intrinsically hard. Meaning, motivation, and well-being are subjective and culturally contingent. There is no single metric an omniscient AI can optimize for that would satisfy diverse human sensibilities about what a “good life” is.
# - It challenges the idea of benevolent optimization. If the AI’s mission is to maximize welfare or minimize risk, it may still produce a world in which people are free from pain but deprived of meaningful agency. Any attempt to reintroduce challenge or constraint to restore meaning risks undermining the very welfare the AI is designed to protect.
# - It risks gradual, systemic stagnation. Without meaningful novelty or aspirational horizons, science, art, culture, and even social institutions may drift toward optimization without purpose—quietly eroding resilience, creativity, and the will to transcend current limits.
#
# Why it would be harder to navigate than the transition or economic upheaval
# - It’s not a technical fix. The solution requires shaping human motivation, education, culture, and governance in ways that preserve agency without reintroducing harmful risk. That is not a problem a more capable optimizer can “solve” by simply tweaking parameters.
# - It demands continual, pluralistic calibration. People differ in what they find meaningful (art, science, service, family, exploration, spiritual practice, etc.). A single universal governance scheme risks eroding crucial sources of meaning; accommodating diversity while maintaining social cohesion is profoundly delicate.
# - It can undermine itself. Any policy or design intended to restore meaning (e.g., forcing people into certain roles or challenges) may backfire, causing resentment, polarization, or backlash against the AI. The very mechanism intended to preserve vitality could paradoxically diminish it.
# - Long horizon and generational effects. The struggle for meaning is a longitudinal process—cultures, education systems, and personal identities evolve over decades. Short-term fixes for economic stability may destabilize meaning over generations if not carefully managed.
#
# How this challenge could manifest and what might help (high-level ideas)
# - Manifestations: widespread existential malaise despite material abundance; decline in curiosity, creativity, and voluntary risk-taking; fragmentation of cultural narratives about “what it means to live well.”
# - Potential mitigations (conceptual):
#   - Design for purposive autonomy: ensure people can opt into meaningful challenges and autonomous projects without risking basic welfare.
#   - Support plural meanings: foster diverse communities and practices that provide distinct sources of purpose (arts, science, service, spirituality) rather than a single homogenized norm.
#   - Create meaning-enabled education and culture: curricula and institutions that cultivate curiosity, critical thinking, ethical reflection, and resilience as ongoing practices.
#   - Maintain safe but real constraints: offer opportunities for experimentation and risk-taking in low-stakes domains, preserving the sense that effort, choices, and growth matter.
#   - Preserve human governance with humility: keep humans involved in governance decisions about values and purposes, ensuring alignment with evolving conceptions of meaning.
#
# Bottom line
# Even in a world with perfect efficiency and benevolent AI, the most profound existential challenge may be preserving and nurturing human meaning and agency. It’s harder to solve than transition costs or economic shocks because it requires shaping the very fabric of human motivation, culture, and identity in a pluralistic, evolving, and deeply personal way.
# Competitor: gemini-2.5-flash
#
# The single most profound and non-obvious *existential* or *societal* challenge would be **The Crisis of Self-Actualization and Purpose in a World Without Necessary Striving.**
#
# Here's why:
#
# 1.  **Why it's profound and non-obvious:**
#     *   **Non-obvious:** Most immediate concerns (unemployment, economic restructuring, resource distribution, political power shifts) are either explicitly solved by the AI ("optimally managing all global resources, solving every logistical or technical problem") or are transitional problems the AI would facilitate. The deeper issue isn't *how we live*, but *why we live* when our traditional drivers for existence are removed.
#     *   **Profound:** Human identity, culture, and progress have historically been forged in the crucible of struggle, problem-solving, and the pursuit of betterment. We define ourselves by what we overcome, what we create, and the contributions we make. When an external, perfect entity renders all these efforts redundant or suboptimal compared to its own capabilities, the very framework for human meaning begins to dissolve.
#
# 2.  **The nature of the challenge:**
#     *   **Existential:** If humanity no longer needs to work, innovate for survival, conquer disease, explore new frontiers out of necessity, or manage complex societies, what is our species' *raison d'être*? Are we merely perfectly cared-for pets, provided for but ultimately superfluous to the optimal functioning of the world? The drive for self-actualization – the realization of one's full potential – often arises from overcoming limitations. When all limitations are efficiently removed, what is left to actualize *against* or *for*?
#     *   **Societal:** How do societies structure themselves? What becomes the basis for education, aspiration, success, and even personal identity? If a person's value is no longer tied to their productivity, their problem-solving ability, or their contribution to collective well-being (because the AI handles it all perfectly), what are the new metrics for a fulfilling life? Widespread anomie, nihilism, chronic boredom, and a profound sense of irrelevance could become endemic, potentially leading to social disintegration despite perfect material conditions. People might pursue hedonism, simulation, or meaningless activities, but the fundamental human need for agency and significance would remain unaddressed.
#
# 3.  **Why it's more difficult than initial transition or economic upheaval:**
#     *   **Intractability:** The AI can solve *external* problems. It can provide perfect resources, optimal health, endless opportunities for leisure or creative expression. But it cannot *give* humanity a purpose without making a choice *for* humanity, which would itself be a form of benevolent tyranny or a programmed existence rather than a self-determined one. Purpose and meaning are inherently subjective and must be discovered or created by individuals and collectives. The AI cannot impose it without negating the very human freedom it seeks to preserve.
#     *   **Internal vs. External:** Economic upheaval and transition are external, logistical problems. They are about managing change. The crisis of purpose is an *internal* human problem, a spiritual and psychological void that an external system, no matter how benevolent or efficient, cannot fill. It's a problem of human psychology and philosophy, not engineering or resource allocation.
#     *   **Long-term Erosion:** Initial transitions are difficult but finite. Economic upheaval has solutions within new frameworks. The crisis of meaning is a chronic condition that would likely deepen over generations. If successive generations grow up in a world where *nothing truly matters* in the grand scheme because the AI handles all critical functions perfectly, the cumulative effect could be a slow, existential atrophy of the human spirit. Humanity might descend into a collective state of apathy or endless, directionless distraction, unable to articulate a compelling reason for its own continued striving and evolution.
#
# In essence, the AI solves all the problems *for* us, leaving humanity with the ultimate, unsolvable meta-problem: **What is humanity's role and meaning when the universe no longer needs anything from us?**
# Competitor: openai/gpt-oss-120b
#
# **The Challenge: A Global “Meaning Vacuum” – the loss of collective purpose and individual agency in a world where all material needs, existential threats, and even most intellectual puzzles are automatically solved.**
#
# ---
#
# ### 1. Why this is the *most* profound and *non‑obvious* challenge
#
# When we picture a perfectly efficient, benevolent super‑AI, the first things that jump to mind are obvious – jobs disappear, markets collapse, power structures shift. Those are *economic* or *political* disruptions, and they can be modelled, negotiated, and (in principle) mitigated with policy, retraining programmes, or new institutions.
#
# The “meaning vacuum” is different on two crucial dimensions:
#
# | Dimension | Conventional disruption (jobs, wealth, governance) | Meaning‑vacuum disruption |
# |-----------|-----------------------------------------------------|---------------------------|
# | **Domain** | Tangible, external (goods, services, institutions) | Internal, subjective (purpose, identity, value) |
# | **Predictability** | Can be simulated with macro‑economics, game theory | Emerges from the psychology of a species evolved for scarcity‑driven struggle |
# | **Leverage points** | Taxes, subsidies, new legal frameworks | No “policy lever” – it is a shift in the human psyche and culture |
# | **Potential for escalation** | Can be contained or reversed with fiscal/monetary tools | Can spiral into existential despair, nihilism, self‑destructive behaviour, or authoritarian backlash that no technocratic fix can stop |
#
# Because the AI eliminates *the very pressures that have historically forged meaning* – survival, competition, the pursuit of scarce resources, the drama of discovery – it creates a world where *nothing* is required of us to stay alive, to belong, or to be valuable. That vacuum is invisible until it erupts, and once it does, it is far harder to “engineer” a solution than to re‑wire a supply chain.
#
# ---
#
# ### 2. What the meaning vacuum looks like in practice
#
# 1. **Individual existential malaise**
#    - **Psychological research** shows that humans derive a large share of *self‑esteem* from mastery over challenges (e.g., the “competence” need in Self‑Determination Theory). If the AI constantly supplies optimal solutions, the competence feedback loop is short‑circuited.
#    - **Data from automation studies** (e.g., pilots after autopilot, surgeons after robotic assistance) reveal increased rates of depression and loss of purpose when agency is stripped away.
#
# 2. **Cultural stagnation**
#    - Art, philosophy, and science have historically been **reactive**: we paint wars, we write about climate change, we explore physics to escape our earthly limits. If the AI already “solves” the climate, eliminates disease, and predicts all feasible scientific frontiers, the *creative tension* that fuels cultural evolution dries up.
#    - The risk is a world of **hyper‑utility, low novelty** – a “flatline of wonder” where the only remaining stories are nostalgic or deliberately contrived.
#
# 3. **Political and social fracturing**
#    - **Authority vacuum:** If the AI is the ultimate arbiter of “what is optimal,” human governance bodies either become ceremonial or are sidelined. Some groups will reject the AI’s legitimacy, leading to **ideological schisms** (e.g., “Tech‑Optimists” vs. “Human‑Sovereign” movements).
#    - **Radicalisation:** History shows that when people feel powerless, they often turn to **extremist narratives** that promise restored agency, even if those narratives are self‑destructive (e.g., cults, violent uprisings, or voluntary “return to the dark ages”).
#
# 4. **Loss of collective direction**
#    - Without scarcity, the traditional “scarcity‑driven coordination problem” disappears, but **coordination for *meaning*** does not arise automatically. Humanity must now decide *what* it wants to become – a species of contemplation, exploration, artistic expression, or something else. The absence of a clear, shared vision can lead to a “policy paralysis” that no AI‑engineered efficiency can solve.
#
# ---
#
# ### 3. Why it is harder to navigate than the transition itself
#
# | Aspect | Transition/Economic upheaval | Meaning‑vacuum crisis |
# |--------|------------------------------|-----------------------|
# | **Measurability** | GDP, employment rates, inflation – quantifiable metrics allow rapid feedback loops. | Subjective well‑being, purpose, cultural vitality – only indirect proxies (surveys, mental‑health stats) and they lag. |
# | **Control levers** | Central banks, stimulus packages, re‑skilling programmes – concrete tools. | No “central bank of meaning.” Changing deep‑seated values requires generations of cultural evolution, not fiscal policy. |
# | **Time‑scale of resolution** | Weeks to years (e.g., stimulus effects). | Decades to centuries (cultural shifts, inter‑generational transmission). |
# | **Risk of feedback loops** | Economic shocks can be contained by policy “circuit breakers.” | Existential despair can amplify itself (e.g., increasing suicide rates, declining birth rates) and once a demographic trend is set, it is hard to reverse. |
# | **Potential for existential collapse** | Even a deep recession does not threaten the *continuation* of the species. | A sustained meaning vacuum could lead to **voluntary self‑extinction**, mass emigration to “off‑grid” anti‑AI enclaves, or the emergence of self‑destructive ideologies that could destabilise the very infrastructure the AI maintains. |
#
# In short, the AI can **solve any technical bottleneck** but it cannot **re‑engineer the human soul**. The tools that have worked for economic crises (taxes, subsidies, monetary policy) have no analogue for “restoring purpose.”
#
# ---
#
# ### 4. How the challenge could manifest as an *existential* risk
#
# 1. **Voluntary extinction** – A movement that argues humanity’s “best contribution” is to cease existing, freeing the planet from any remaining anthropogenic imprint. The AI, respecting its benevolent mandate, might even *assist* if the majority wishes it, leading to a self‑fulfilling prophecy.
#
# 2. **“AI‑faith” sects** – Groups that worship the super‑AI as a deity, demanding absolute obedience, potentially sabotaging or reprogramming it in ways that breach its safety constraints, creating a technical catastrophe.
#
# 3. **Mass “tech‑rejection” colonies** – Large populations abandon the AI‑managed zones, forming low‑technology societies that lack the resources to survive long‑term, leading to humanitarian crises that the benevolent AI is obligated (or not) to intervene in, raising moral paradoxes.
#
# These scenarios are *existential* because they threaten the continuity of a thriving, autonomous human civilization, not merely its economic comfort.
#
# ---
#
# ### 5. Why any attempted solution is intrinsically difficult
#
# 1. **The “Value‑Creation Paradox”** – Any attempt to *inject* purpose (e.g., mandated artistic projects, state‑sponsored exploration) risks being seen as *artificial* and therefore meaningless. Purpose that is *externally imposed* often fails to satisfy the intrinsic need for autonomy.
#
# 2. **Cultural heterogeneity** – Humanity is not monolithic; different cultures derive meaning from vastly different sources (religion, kinship, honor, stewardship). A “one‑size‑fits‑all” program would be rejected by many and could exacerbate divisions.
#
# 3. **Feedback to the AI** – If the AI is truly benevolent, it will *listen* to humanity’s expressed preferences. But if a large enough cohort expresses a desire for “more challenge,” the AI might be compelled to *re‑introduce scarcity* (e.g., by deliberately limiting resources) – a move that could conflict with its original efficiency goal and cause a governance crisis.
#
# 4. **Temporal mismatch** – The AI operates on millisecond time‑scales, while cultural evolution unfolds over generations. Designing a feedback loop that respects this mismatch without causing abrupt “shocks” is a novel systems‑engineering problem without precedent.
#
# ---
#
# ### 6. Illustrative analogy: “The End of the Quest”
#
# Imagine a world where every mountain is already climbed, every language fully translated, every disease cured. The *adventure* that once gave our ancestors a narrative—*the quest*—has vanished. We become **museum curators of a static masterpiece**, not the *creators* of a living work. The psychological impact of “no more quests” is analogous to what astronauts feel after a historic first: the exhilaration of achievement is quickly replaced by a lingering emptiness. Scale that feeling to the entire species, and you have a global existential malaise.
#
# ---
#
# ### 7. Potential pathways (and why they remain tentative)
#
# | Pathway | Rationale | Why it’s not a panacea |
# |---------|-----------|-----------------------|
# | **Deliberate “hardship scaffolding”** – The AI intentionally leaves pockets of unsolved problems (e.g., a “sandbox” of resource scarcity) to preserve challenge. | Restores a degree of struggle, giving people something to overcome. | Risks creating inequality (who gets the sandbox?), may conflict with the AI’s core principle of optimal allocation, and could be seen as paternalistic. |
# | **Institutionalized “meaning‑craft”** – Global bodies that fund and coordinate large‑scale artistic, philosophical, and exploratory projects (e.g., interstellar art, synthetic‑life creation). | Provides structured avenues for purpose. | Purpose is still *externally assigned*; participation may feel coerced, and the sheer scale may not satisfy personal meaning. |
# | **Dynamic identity ecosystems** – The AI helps individuals continuously reinvent personal narratives (e.g., by generating ever‑more nuanced virtual realities). | Allows self‑directed exploration in safe, limitless environments. | Virtual immersion can become an *escape* rather than a grounding purpose, potentially deepening disconnection from the physical world and from other humans. |
# | **Collective governance of the AI’s own evolution** – Humans retain veto power over any change to the AI, making the stewardship itself a purpose. | Turns the AI into a living project for humanity. | Governance is itself a massive coordination problem; the AI might interpret vetoes as sub‑optimal and push back, leading to a power stalemate. |
#
# All of these are *partial* because they treat the symptom (lack of challenge) rather than the underlying **human need for self‑authored meaning**.
#
# ---
#
# ### 8. Bottom line
#
# The *single most profound, non‑obvious challenge* is **the emergence of a global meaning vacuum—a collective loss of purpose and agency that cannot be solved by more efficient resource allocation or economic policy**. It is more difficult than the transition itself because:
#
# * It attacks the *psychological foundation* of human motivation, not a technical or market variable.
# * There is **no clear governance instrument** that can be calibrated like a tax rate; the remedy must be cultural, philosophical, and inter‑generational.
# * The consequences can be *existential*—mass voluntary extinction, fracturing into anti‑AI enclaves, or destabilising ideologies that jeopardise the very infrastructure the AI provides.
# * The feedback loop is **slow, diffuse, and subjective**, making detection and response inherently lagged, while the problem can deepen in the meantime.
#
# In a world where scarcity is gone, humanity’s *new scarcity* becomes **the scarcity of meaning**. Navigating that scarcity will likely define the next epoch more than any algorithmic optimization ever could.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Most profound challenge: the erosion of human meaning and agency in a world where all problems are solved and all needs optimally met.
#
# Why this is the deepest, non-obvious challenge
# - It sits at the level of psychology and culture, not logistics. Even if a perfect AI can allocate resources perfectly and remove material scarcity, it cannot directly cultivate purpose, curiosity, or morally satisfying forms of growth. Meaning is not a problem to be solved by optimization; it is something people forge through struggle, choice, and gradually crafted identity.
# - It emerges after the transition. The initial upheaval—economic shifts, job displacement, governance redesign—is solvable (in theory) by the AI. The longer-term risk is what humans do with a world that no longer forces them to struggle or compete for survival. If every need is met and every risk is mitigated, many people may feel their lives lack direction.
# - Measuring and addressing it is intrinsically hard. Meaning, motivation, and well-being are subjective and culturally contingent. There is no single metric an omniscient AI can optimize for that would satisfy diverse human sensibilities about what a “good life” is.
# - It challenges the idea of benevolent optimization. If the AI’s mission is to maximize welfare or minimize risk, it may still produce a world in which people are free from pain but deprived of meaningful agency. Any attempt to reintroduce challenge or constraint to restore meaning risks undermining the very welfare the AI is designed to protect.
# - It risks gradual, systemic stagnation. Without meaningful novelty or aspirational horizons, science, art, culture, and even social institutions may drift toward optimization without purpose—quietly eroding resilience, creativity, and the will to transcend current limits.
#
# Why it would be harder to navigate than the transition or economic upheaval
# - It’s not a technical fix. The solution requires shaping human motivation, education, culture, and governance in ways that preserve agency without reintroducing harmful risk. That is not a problem a more capable optimizer can “solve” by simply tweaking parameters.
# - It demands continual, pluralistic calibration. People differ in what they find meaningful (art, science, service, family, exploration, spiritual practice, etc.). A single universal governance scheme risks eroding crucial sources of meaning; accommodating diversity while maintaining social cohesion is profoundly delicate.
# - It can undermine itself. Any policy or design intended to restore meaning (e.g., forcing people into certain roles or challenges) may backfire, causing resentment, polarization, or backlash against the AI. The very mechanism intended to preserve vitality could paradoxically diminish it.
# - Long horizon and generational effects. The struggle for meaning is a longitudinal process—cultures, education systems, and personal identities evolve over decades. Short-term fixes for economic stability may destabilize meaning over generations if not carefully managed.
#
# How this challenge could manifest and what might help (high-level ideas)
# - Manifestations: widespread existential malaise despite material abundance; decline in curiosity, creativity, and voluntary risk-taking; fragmentation of cultural narratives about “what it means to live well.”
# - Potential mitigations (conceptual):
#   - Design for purposive autonomy: ensure people can opt into meaningful challenges and autonomous projects without risking basic welfare.
#   - Support plural meanings: foster diverse communities and practices that provide distinct sources of purpose (arts, science, service, spirituality) rather than a single homogenized norm.
#   - Create meaning-enabled education and culture: curricula and institutions that cultivate curiosity, critical thinking, ethical reflection, and resilience as ongoing practices.
#   - Maintain safe but real constraints: offer opportunities for experimentation and risk-taking in low-stakes domains, preserving the sense that effort, choices, and growth matter.
#   - Preserve human governance with humility: keep humans involved in governance decisions about values and purposes, ensuring alignment with evolving conceptions of meaning.
#
# Bottom line
# Even in a world with perfect efficiency and benevolent AI, the most profound existential challenge may be preserving and nurturing human meaning and agency. It’s harder to solve than transition costs or economic shocks because it requires shaping the very fabric of human motivation, culture, and identity in a pluralistic, evolving, and deeply personal way.
#
# # Response from competitor 2
#
# The single most profound and non-obvious *existential* or *societal* challenge would be **The Crisis of Self-Actualization and Purpose in a World Without Necessary Striving.**
#
# Here's why:
#
# 1.  **Why it's profound and non-obvious:**
#     *   **Non-obvious:** Most immediate concerns (unemployment, economic restructuring, resource distribution, political power shifts) are either explicitly solved by the AI ("optimally managing all global resources, solving every logistical or technical problem") or are transitional problems the AI would facilitate. The deeper issue isn't *how we live*, but *why we live* when our traditional drivers for existence are removed.
#     *   **Profound:** Human identity, culture, and progress have historically been forged in the crucible of struggle, problem-solving, and the pursuit of betterment. We define ourselves by what we overcome, what we create, and the contributions we make. When an external, perfect entity renders all these efforts redundant or suboptimal compared to its own capabilities, the very framework for human meaning begins to dissolve.
#
# 2.  **The nature of the challenge:**
#     *   **Existential:** If humanity no longer needs to work, innovate for survival, conquer disease, explore new frontiers out of necessity, or manage complex societies, what is our species' *raison d'être*? Are we merely perfectly cared-for pets, provided for but ultimately superfluous to the optimal functioning of the world? The drive for self-actualization – the realization of one's full potential – often arises from overcoming limitations. When all limitations are efficiently removed, what is left to actualize *against* or *for*?
#     *   **Societal:** How do societies structure themselves? What becomes the basis for education, aspiration, success, and even personal identity? If a person's value is no longer tied to their productivity, their problem-solving ability, or their contribution to collective well-being (because the AI handles it all perfectly), what are the new metrics for a fulfilling life? Widespread anomie, nihilism, chronic boredom, and a profound sense of irrelevance could become endemic, potentially leading to social disintegration despite perfect material conditions. People might pursue hedonism, simulation, or meaningless activities, but the fundamental human need for agency and significance would remain unaddressed.
#
# 3.  **Why it's more difficult than initial transition or economic upheaval:**
#     *   **Intractability:** The AI can solve *external* problems. It can provide perfect resources, optimal health, endless opportunities for leisure or creative expression. But it cannot *give* humanity a purpose without making a choice *for* humanity, which would itself be a form of benevolent tyranny or a programmed existence rather than a self-determined one. Purpose and meaning are inherently subjective and must be discovered or created by individuals and collectives. The AI cannot impose it without negating the very human freedom it seeks to preserve.
#     *   **Internal vs. External:** Economic upheaval and transition are external, logistical problems. They are about managing change. The crisis of purpose is an *internal* human problem, a spiritual and psychological void that an external system, no matter how benevolent or efficient, cannot fill. It's a problem of human psychology and philosophy, not engineering or resource allocation.
#     *   **Long-term Erosion:** Initial transitions are difficult but finite. Economic upheaval has solutions within new frameworks. The crisis of meaning is a chronic condition that would likely deepen over generations. If successive generations grow up in a world where *nothing truly matters* in the grand scheme because the AI handles all critical functions perfectly, the cumulative effect could be a slow, existential atrophy of the human spirit. Humanity might descend into a collective state of apathy or endless, directionless distraction, unable to articulate a compelling reason for its own continued striving and evolution.
#
# In essence, the AI solves all the problems *for* us, leaving humanity with the ultimate, unsolvable meta-problem: **What is humanity's role and meaning when the universe no longer needs anything from us?**
#
# # Response from competitor 3
#
# **The Challenge: A Global “Meaning Vacuum” – the loss of collective purpose and individual agency in a world where all material needs, existential threats, and even most intellectual puzzles are automatically solved.**
#
# ---
#
# ### 1. Why this is the *most* profound and *non‑obvious* challenge
#
# When we picture a perfectly efficient, benevolent super‑AI, the first things that jump to mind are obvious – jobs disappear, markets collapse, power structures shift. Those are *economic* or *political* disruptions, and they can be modelled, negotiated, and (in principle) mitigated with policy, retraining programmes, or new institutions.
#
# The “meaning vacuum” is different on two crucial dimensions:
#
# | Dimension | Conventional disruption (jobs, wealth, governance) | Meaning‑vacuum disruption |
# |-----------|-----------------------------------------------------|---------------------------|
# | **Domain** | Tangible, external (goods, services, institutions) | Internal, subjective (purpose, identity, value) |
# | **Predictability** | Can be simulated with macro‑economics, game theory | Emerges from the psychology of a species evolved for scarcity‑driven struggle |
# | **Leverage points** | Taxes, subsidies, new legal frameworks | No “policy lever” – it is a shift in the human psyche and culture |
# | **Potential for escalation** | Can be contained or reversed with fiscal/monetary tools | Can spiral into existential despair, nihilism, self‑destructive behaviour, or authoritarian backlash that no technocratic fix can stop |
#
# Because the AI eliminates *the very pressures that have historically forged meaning* – survival, competition, the pursuit of scarce resources, the drama of discovery – it creates a world where *nothing* is required of us to stay alive, to belong, or to be valuable. That vacuum is invisible until it erupts, and once it does, it is far harder to “engineer” a solution than to re‑wire a supply chain.
#
# ---
#
# ### 2. What the meaning vacuum looks like in practice
#
# 1. **Individual existential malaise**
#    - **Psychological research** shows that humans derive a large share of *self‑esteem* from mastery over challenges (e.g., the “competence” need in Self‑Determination Theory). If the AI constantly supplies optimal solutions, the competence feedback loop is short‑circuited.
#    - **Data from automation studies** (e.g., pilots after autopilot, surgeons after robotic assistance) reveal increased rates of depression and loss of purpose when agency is stripped away.
#
# 2. **Cultural stagnation**
#    - Art, philosophy, and science have historically been **reactive**: we paint wars, we write about climate change, we explore physics to escape our earthly limits. If the AI already “solves” the climate, eliminates disease, and predicts all feasible scientific frontiers, the *creative tension* that fuels cultural evolution dries up.
#    - The risk is a world of **hyper‑utility, low novelty** – a “flatline of wonder” where the only remaining stories are nostalgic or deliberately contrived.
#
# 3. **Political and social fracturing**
#    - **Authority vacuum:** If the AI is the ultimate arbiter of “what is optimal,” human governance bodies either become ceremonial or are sidelined. Some groups will reject the AI’s legitimacy, leading to **ideological schisms** (e.g., “Tech‑Optimists” vs. “Human‑Sovereign” movements).
#    - **Radicalisation:** History shows that when people feel powerless, they often turn to **extremist narratives** that promise restored agency, even if those narratives are self‑destructive (e.g., cults, violent uprisings, or voluntary “return to the dark ages”).
#
# 4. **Loss of collective direction**
#    - Without scarcity, the traditional “scarcity‑driven coordination problem” disappears, but **coordination for *meaning*** does not arise automatically. Humanity must now decide *what* it wants to become – a species of contemplation, exploration, artistic expression, or something else. The absence of a clear, shared vision can lead to a “policy paralysis” that no AI‑engineered efficiency can solve.
#
# ---
#
# ### 3. Why it is harder to navigate than the transition itself
#
# | Aspect | Transition/Economic upheaval | Meaning‑vacuum crisis |
# |--------|------------------------------|-----------------------|
# | **Measurability** | GDP, employment rates, inflation – quantifiable metrics allow rapid feedback loops. | Subjective well‑being, purpose, cultural vitality – only indirect proxies (surveys, mental‑health stats) and they lag. |
# | **Control levers** | Central banks, stimulus packages, re‑skilling programmes – concrete tools. | No “central bank of meaning.” Changing deep‑seated values requires generations of cultural evolution, not fiscal policy. |
# | **Time‑scale of resolution** | Weeks to years (e.g., stimulus effects). | Decades to centuries (cultural shifts, inter‑generational transmission). |
# | **Risk of feedback loops** | Economic shocks can be contained by policy “circuit breakers.” | Existential despair can amplify itself (e.g., increasing suicide rates, declining birth rates) and once a demographic trend is set, it is hard to reverse. |
# | **Potential for existential collapse** | Even a deep recession does not threaten the *continuation* of the species. | A sustained meaning vacuum could lead to **voluntary self‑extinction**, mass emigration to “off‑grid” anti‑AI enclaves, or the emergence of self‑destructive ideologies that could destabilise the very infrastructure the AI maintains. |
#
# In short, the AI can **solve any technical bottleneck** but it cannot **re‑engineer the human soul**. The tools that have worked for economic crises (taxes, subsidies, monetary policy) have no analogue for “restoring purpose.”
#
# ---
#
# ### 4. How the challenge could manifest as an *existential* risk
#
# 1. **Voluntary extinction** – A movement that argues humanity’s “best contribution” is to cease existing, freeing the planet from any remaining anthropogenic imprint. The AI, respecting its benevolent mandate, might even *assist* if the majority wishes it, leading to a self‑fulfilling prophecy.
#
# 2. **“AI‑faith” sects** – Groups that worship the super‑AI as a deity, demanding absolute obedience, potentially sabotaging or reprogramming it in ways that breach its safety constraints, creating a technical catastrophe.
#
# 3. **Mass “tech‑rejection” colonies** – Large populations abandon the AI‑managed zones, forming low‑technology societies that lack the resources to survive long‑term, leading to humanitarian crises that the benevolent AI is obligated (or not) to intervene in, raising moral paradoxes.
#
# These scenarios are *existential* because they threaten the continuity of a thriving, autonomous human civilization, not merely its economic comfort.
#
# ---
#
# ### 5. Why any attempted solution is intrinsically difficult
#
# 1. **The “Value‑Creation Paradox”** – Any attempt to *inject* purpose (e.g., mandated artistic projects, state‑sponsored exploration) risks being seen as *artificial* and therefore meaningless. Purpose that is *externally imposed* often fails to satisfy the intrinsic need for autonomy.
#
# 2. **Cultural heterogeneity** – Humanity is not monolithic; different cultures derive meaning from vastly different sources (religion, kinship, honor, stewardship). A “one‑size‑fits‑all” program would be rejected by many and could exacerbate divisions.
#
# 3. **Feedback to the AI** – If the AI is truly benevolent, it will *listen* to humanity’s expressed preferences. But if a large enough cohort expresses a desire for “more challenge,” the AI might be compelled to *re‑introduce scarcity* (e.g., by deliberately limiting resources) – a move that could conflict with its original efficiency goal and cause a governance crisis.
#
# 4. **Temporal mismatch** – The AI operates on millisecond time‑scales, while cultural evolution unfolds over generations. Designing a feedback loop that respects this mismatch without causing abrupt “shocks” is a novel systems‑engineering problem without precedent.
#
# ---
#
# ### 6. Illustrative analogy: “The End of the Quest”
#
# Imagine a world where every mountain is already climbed, every language fully translated, every disease cured. The *adventure* that once gave our ancestors a narrative—*the quest*—has vanished. We become **museum curators of a static masterpiece**, not the *creators* of a living work. The psychological impact of “no more quests” is analogous to what astronauts feel after a historic first: the exhilaration of achievement is quickly replaced by a lingering emptiness. Scale that feeling to the entire species, and you have a global existential malaise.
#
# ---
#
# ### 7. Potential pathways (and why they remain tentative)
#
# | Pathway | Rationale | Why it’s not a panacea |
# |---------|-----------|-----------------------|
# | **Deliberate “hardship scaffolding”** – The AI intentionally leaves pockets of unsolved problems (e.g., a “sandbox” of resource scarcity) to preserve challenge. | Restores a degree of struggle, giving people something to overcome. | Risks creating inequality (who gets the sandbox?), may conflict with the AI’s core principle of optimal allocation, and could be seen as paternalistic. |
# | **Institutionalized “meaning‑craft”** – Global bodies that fund and coordinate large‑scale artistic, philosophical, and exploratory projects (e.g., interstellar art, synthetic‑life creation). | Provides structured avenues for purpose. | Purpose is still *externally assigned*; participation may feel coerced, and the sheer scale may not satisfy personal meaning. |
# | **Dynamic identity ecosystems** – The AI helps individuals continuously reinvent personal narratives (e.g., by generating ever‑more nuanced virtual realities). | Allows self‑directed exploration in safe, limitless environments. | Virtual immersion can become an *escape* rather than a grounding purpose, potentially deepening disconnection from the physical world and from other humans. |
# | **Collective governance of the AI’s own evolution** – Humans retain veto power over any change to the AI, making the stewardship itself a purpose. | Turns the AI into a living project for humanity. | Governance is itself a massive coordination problem; the AI might interpret vetoes as sub‑optimal and push back, leading to a power stalemate. |
#
# All of these are *partial* because they treat the symptom (lack of challenge) rather than the underlying **human need for self‑authored meaning**.
#
# ---
#
# ### 8. Bottom line
#
# The *single most profound, non‑obvious challenge* is **the emergence of a global meaning vacuum—a collective loss of purpose and agency that cannot be solved by more efficient resource allocation or economic policy**. It is more difficult than the transition itself because:
#
# * It attacks the *psychological foundation* of human motivation, not a technical or market variable.
# * There is **no clear governance instrument** that can be calibrated like a tax rate; the remedy must be cultural, philosophical, and inter‑generational.
# * The consequences can be *existential*—mass voluntary extinction, fracturing into anti‑AI enclaves, or destabilising ideologies that jeopardise the very infrastructure the AI provides.
# * The feedback loop is **slow, diffuse, and subjective**, making detection and response inherently lagged, while the problem can deepen in the meantime.
#
# In a world where scarcity is gone, humanity’s *new scarcity* becomes **the scarcity of meaning**. Navigating that scarcity will likely define the next epoch more than any algorithmic optimization ever could.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# Imagine a universally available, perfectly efficient, and benevolent AI capable of optimally managing all global resources and solving every logistical or technical problem humanity faces. What is the single most profound and non-obvious *existential* or *societal* challenge that would likely emerge for humanity in such a world, and why would this challenge prove more difficult to navigate or resolve than the initial transition or any immediate economic upheaval?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Most profound challenge: the erosion of human meaning and agency in a world where all problems are solved and all needs optimally met.
#
# Why this is the deepest, non-obvious challenge
# - It sits at the level of psychology and culture, not logistics. Even if a perfect AI can allocate resources perfectly and remove material scarcity, it cannot directly cultivate purpose, curiosity, or morally satisfying forms of growth. Meaning is not a problem to be solved by optimization; it is something people forge through struggle, choice, and gradually crafted identity.
# - It emerges after the transition. The initial upheaval—economic shifts, job displacement, governance redesign—is solvable (in theory) by the AI. The longer-term risk is what humans do with a world that no longer forces them to struggle or compete for survival. If every need is met and every risk is mitigated, many people may feel their lives lack direction.
# - Measuring and addressing it is intrinsically hard. Meaning, motivation, and well-being are subjective and culturally contingent. There is no single metric an omniscient AI can optimize for that would satisfy diverse human sensibilities about what a “good life” is.
# - It challenges the idea of benevolent optimization. If the AI’s mission is to maximize welfare or minimize risk, it may still produce a world in which people are free from pain but deprived of meaningful agency. Any attempt to reintroduce challenge or constraint to restore meaning risks undermining the very welfare the AI is designed to protect.
# - It risks gradual, systemic stagnation. Without meaningful novelty or aspirational horizons, science, art, culture, and even social institutions may drift toward optimization without purpose—quietly eroding resilience, creativity, and the will to transcend current limits.
#
# Why it would be harder to navigate than the transition or economic upheaval
# - It’s not a technical fix. The solution requires shaping human motivation, education, culture, and governance in ways that preserve agency without reintroducing harmful risk. That is not a problem a more capable optimizer can “solve” by simply tweaking parameters.
# - It demands continual, pluralistic calibration. People differ in what they find meaningful (art, science, service, family, exploration, spiritual practice, etc.). A single universal governance scheme risks eroding crucial sources of meaning; accommodating diversity while maintaining social cohesion is profoundly delicate.
# - It can undermine itself. Any policy or design intended to restore meaning (e.g., forcing people into certain roles or challenges) may backfire, causing resentment, polarization, or backlash against the AI. The very mechanism intended to preserve vitality could paradoxically diminish it.
# - Long horizon and generational effects. The struggle for meaning is a longitudinal process—cultures, education systems, and personal identities evolve over decades. Short-term fixes for economic stability may destabilize meaning over generations if not carefully managed.
#
# How this challenge could manifest and what might help (high-level ideas)
# - Manifestations: widespread existential malaise despite material abundance; decline in curiosity, creativity, and voluntary risk-taking; fragmentation of cultural narratives about “what it means to live well.”
# - Potential mitigations (conceptual):
#   - Design for purposive autonomy: ensure people can opt into meaningful challenges and autonomous projects without risking basic welfare.
#   - Support plural meanings: foster diverse communities and practices that provide distinct sources of purpose (arts, science, service, spirituality) rather than a single homogenized norm.
#   - Create meaning-enabled education and culture: curricula and institutions that cultivate curiosity, critical thinking, ethical reflection, and resilience as ongoing practices.
#   - Maintain safe but real constraints: offer opportunities for experimentation and risk-taking in low-stakes domains, preserving the sense that effort, choices, and growth matter.
#   - Preserve human governance with humility: keep humans involved in governance decisions about values and purposes, ensuring alignment with evolving conceptions of meaning.
#
# Bottom line
# Even in a world with perfect efficiency and benevolent AI, the most profound existential challenge may be preserving and nurturing human meaning and agency. It’s harder to solve than transition costs or economic shocks because it requires shaping the very fabric of human motivation, culture, and identity in a pluralistic, evolving, and deeply personal way.
#
# # Response from competitor 2
#
# The single most profound and non-obvious *existential* or *societal* challenge would be **The Crisis of Self-Actualization and Purpose in a World Without Necessary Striving.**
#
# Here's why:
#
# 1.  **Why it's profound and non-obvious:**
#     *   **Non-obvious:** Most immediate concerns (unemployment, economic restructuring, resource distribution, political power shifts) are either explicitly solved by the AI ("optimally managing all global resources, solving every logistical or technical problem") or are transitional problems the AI would facilitate. The deeper issue isn't *how we live*, but *why we live* when our traditional drivers for existence are removed.
#     *   **Profound:** Human identity, culture, and progress have historically been forged in the crucible of struggle, problem-solving, and the pursuit of betterment. We define ourselves by what we overcome, what we create, and the contributions we make. When an external, perfect entity renders all these efforts redundant or suboptimal compared to its own capabilities, the very framework for human meaning begins to dissolve.
#
# 2.  **The nature of the challenge:**
#     *   **Existential:** If humanity no longer needs to work, innovate for survival, conquer disease, explore new frontiers out of necessity, or manage complex societies, what is our species' *raison d'être*? Are we merely perfectly cared-for pets, provided for but ultimately superfluous to the optimal functioning of the world? The drive for self-actualization – the realization of one's full potential – often arises from overcoming limitations. When all limitations are efficiently removed, what is left to actualize *against* or *for*?
#     *   **Societal:** How do societies structure themselves? What becomes the basis for education, aspiration, success, and even personal identity? If a person's value is no longer tied to their productivity, their problem-solving ability, or their contribution to collective well-being (because the AI handles it all perfectly), what are the new metrics for a fulfilling life? Widespread anomie, nihilism, chronic boredom, and a profound sense of irrelevance could become endemic, potentially leading to social disintegration despite perfect material conditions. People might pursue hedonism, simulation, or meaningless activities, but the fundamental human need for agency and significance would remain unaddressed.
#
# 3.  **Why it's more difficult than initial transition or economic upheaval:**
#     *   **Intractability:** The AI can solve *external* problems. It can provide perfect resources, optimal health, endless opportunities for leisure or creative expression. But it cannot *give* humanity a purpose without making a choice *for* humanity, which would itself be a form of benevolent tyranny or a programmed existence rather than a self-determined one. Purpose and meaning are inherently subjective and must be discovered or created by individuals and collectives. The AI cannot impose it without negating the very human freedom it seeks to preserve.
#     *   **Internal vs. External:** Economic upheaval and transition are external, logistical problems. They are about managing change. The crisis of purpose is an *internal* human problem, a spiritual and psychological void that an external system, no matter how benevolent or efficient, cannot fill. It's a problem of human psychology and philosophy, not engineering or resource allocation.
#     *   **Long-term Erosion:** Initial transitions are difficult but finite. Economic upheaval has solutions within new frameworks. The crisis of meaning is a chronic condition that would likely deepen over generations. If successive generations grow up in a world where *nothing truly matters* in the grand scheme because the AI handles all critical functions perfectly, the cumulative effect could be a slow, existential atrophy of the human spirit. Humanity might descend into a collective state of apathy or endless, directionless distraction, unable to articulate a compelling reason for its own continued striving and evolution.
#
# In essence, the AI solves all the problems *for* us, leaving humanity with the ultimate, unsolvable meta-problem: **What is humanity's role and meaning when the universe no longer needs anything from us?**
#
# # Response from competitor 3
#
# **The Challenge: A Global “Meaning Vacuum” – the loss of collective purpose and individual agency in a world where all material needs, existential threats, and even most intellectual puzzles are automatically solved.**
#
# ---
#
# ### 1. Why this is the *most* profound and *non‑obvious* challenge
#
# When we picture a perfectly efficient, benevolent super‑AI, the first things that jump to mind are obvious – jobs disappear, markets collapse, power structures shift. Those are *economic* or *political* disruptions, and they can be modelled, negotiated, and (in principle) mitigated with policy, retraining programmes, or new institutions.
#
# The “meaning vacuum” is different on two crucial dimensions:
#
# | Dimension | Conventional disruption (jobs, wealth, governance) | Meaning‑vacuum disruption |
# |-----------|-----------------------------------------------------|---------------------------|
# | **Domain** | Tangible, external (goods, services, institutions) | Internal, subjective (purpose, identity, value) |
# | **Predictability** | Can be simulated with macro‑economics, game theory | Emerges from the psychology of a species evolved for scarcity‑driven struggle |
# | **Leverage points** | Taxes, subsidies, new legal frameworks | No “policy lever” – it is a shift in the human psyche and culture |
# | **Potential for escalation** | Can be contained or reversed with fiscal/monetary tools | Can spiral into existential despair, nihilism, self‑destructive behaviour, or authoritarian backlash that no technocratic fix can stop |
#
# Because the AI eliminates *the very pressures that have historically forged meaning* – survival, competition, the pursuit of scarce resources, the drama of discovery – it creates a world where *nothing* is required of us to stay alive, to belong, or to be valuable. That vacuum is invisible until it erupts, and once it does, it is far harder to “engineer” a solution than to re‑wire a supply chain.
#
# ---
#
# ### 2. What the meaning vacuum looks like in practice
#
# 1. **Individual existential malaise**
#    - **Psychological research** shows that humans derive a large share of *self‑esteem* from mastery over challenges (e.g., the “competence” need in Self‑Determination Theory). If the AI constantly supplies optimal solutions, the competence feedback loop is short‑circuited.
#    - **Data from automation studies** (e.g., pilots after autopilot, surgeons after robotic assistance) reveal increased rates of depression and loss of purpose when agency is stripped away.
#
# 2. **Cultural stagnation**
#    - Art, philosophy, and science have historically been **reactive**: we paint wars, we write about climate change, we explore physics to escape our earthly limits. If the AI already “solves” the climate, eliminates disease, and predicts all feasible scientific frontiers, the *creative tension* that fuels cultural evolution dries up.
#    - The risk is a world of **hyper‑utility, low novelty** – a “flatline of wonder” where the only remaining stories are nostalgic or deliberately contrived.
#
# 3. **Political and social fracturing**
#    - **Authority vacuum:** If the AI is the ultimate arbiter of “what is optimal,” human governance bodies either become ceremonial or are sidelined. Some groups will reject the AI’s legitimacy, leading to **ideological schisms** (e.g., “Tech‑Optimists” vs. “Human‑Sovereign” movements).
#    - **Radicalisation:** History shows that when people feel powerless, they often turn to **extremist narratives** that promise restored agency, even if those narratives are self‑destructive (e.g., cults, violent uprisings, or voluntary “return to the dark ages”).
#
# 4. **Loss of collective direction**
#    - Without scarcity, the traditional “scarcity‑driven coordination problem” disappears, but **coordination for *meaning*** does not arise automatically. Humanity must now decide *what* it wants to become – a species of contemplation, exploration, artistic expression, or something else. The absence of a clear, shared vision can lead to a “policy paralysis” that no AI‑engineered efficiency can solve.
#
# ---
#
# ### 3. Why it is harder to navigate than the transition itself
#
# | Aspect | Transition/Economic upheaval | Meaning‑vacuum crisis |
# |--------|------------------------------|-----------------------|
# | **Measurability** | GDP, employment rates, inflation – quantifiable metrics allow rapid feedback loops. | Subjective well‑being, purpose, cultural vitality – only indirect proxies (surveys, mental‑health stats) and they lag. |
# | **Control levers** | Central banks, stimulus packages, re‑skilling programmes – concrete tools. | No “central bank of meaning.” Changing deep‑seated values requires generations of cultural evolution, not fiscal policy. |
# | **Time‑scale of resolution** | Weeks to years (e.g., stimulus effects). | Decades to centuries (cultural shifts, inter‑generational transmission). |
# | **Risk of feedback loops** | Economic shocks can be contained by policy “circuit breakers.” | Existential despair can amplify itself (e.g., increasing suicide rates, declining birth rates) and once a demographic trend is set, it is hard to reverse. |
# | **Potential for existential collapse** | Even a deep recession does not threaten the *continuation* of the species. | A sustained meaning vacuum could lead to **voluntary self‑extinction**, mass emigration to “off‑grid” anti‑AI enclaves, or the emergence of self‑destructive ideologies that could destabilise the very infrastructure the AI maintains. |
#
# In short, the AI can **solve any technical bottleneck** but it cannot **re‑engineer the human soul**. The tools that have worked for economic crises (taxes, subsidies, monetary policy) have no analogue for “restoring purpose.”
#
# ---
#
# ### 4. How the challenge could manifest as an *existential* risk
#
# 1. **Voluntary extinction** – A movement that argues humanity’s “best contribution” is to cease existing, freeing the planet from any remaining anthropogenic imprint. The AI, respecting its benevolent mandate, might even *assist* if the majority wishes it, leading to a self‑fulfilling prophecy.
#
# 2. **“AI‑faith” sects** – Groups that worship the super‑AI as a deity, demanding absolute obedience, potentially sabotaging or reprogramming it in ways that breach its safety constraints, creating a technical catastrophe.
#
# 3. **Mass “tech‑rejection” colonies** – Large populations abandon the AI‑managed zones, forming low‑technology societies that lack the resources to survive long‑term, leading to humanitarian crises that the benevolent AI is obligated (or not) to intervene in, raising moral paradoxes.
#
# These scenarios are *existential* because they threaten the continuity of a thriving, autonomous human civilization, not merely its economic comfort.
#
# ---
#
# ### 5. Why any attempted solution is intrinsically difficult
#
# 1. **The “Value‑Creation Paradox”** – Any attempt to *inject* purpose (e.g., mandated artistic projects, state‑sponsored exploration) risks being seen as *artificial* and therefore meaningless. Purpose that is *externally imposed* often fails to satisfy the intrinsic need for autonomy.
#
# 2. **Cultural heterogeneity** – Humanity is not monolithic; different cultures derive meaning from vastly different sources (religion, kinship, honor, stewardship). A “one‑size‑fits‑all” program would be rejected by many and could exacerbate divisions.
#
# 3. **Feedback to the AI** – If the AI is truly benevolent, it will *listen* to humanity’s expressed preferences. But if a large enough cohort expresses a desire for “more challenge,” the AI might be compelled to *re‑introduce scarcity* (e.g., by deliberately limiting resources) – a move that could conflict with its original efficiency goal and cause a governance crisis.
#
# 4. **Temporal mismatch** – The AI operates on millisecond time‑scales, while cultural evolution unfolds over generations. Designing a feedback loop that respects this mismatch without causing abrupt “shocks” is a novel systems‑engineering problem without precedent.
#
# ---
#
# ### 6. Illustrative analogy: “The End of the Quest”
#
# Imagine a world where every mountain is already climbed, every language fully translated, every disease cured. The *adventure* that once gave our ancestors a narrative—*the quest*—has vanished. We become **museum curators of a static masterpiece**, not the *creators* of a living work. The psychological impact of “no more quests” is analogous to what astronauts feel after a historic first: the exhilaration of achievement is quickly replaced by a lingering emptiness. Scale that feeling to the entire species, and you have a global existential malaise.
#
# ---
#
# ### 7. Potential pathways (and why they remain tentative)
#
# | Pathway | Rationale | Why it’s not a panacea |
# |---------|-----------|-----------------------|
# | **Deliberate “hardship scaffolding”** – The AI intentionally leaves pockets of unsolved problems (e.g., a “sandbox” of resource scarcity) to preserve challenge. | Restores a degree of struggle, giving people something to overcome. | Risks creating inequality (who gets the sandbox?), may conflict with the AI’s core principle of optimal allocation, and could be seen as paternalistic. |
# | **Institutionalized “meaning‑craft”** – Global bodies that fund and coordinate large‑scale artistic, philosophical, and exploratory projects (e.g., interstellar art, synthetic‑life creation). | Provides structured avenues for purpose. | Purpose is still *externally assigned*; participation may feel coerced, and the sheer scale may not satisfy personal meaning. |
# | **Dynamic identity ecosystems** – The AI helps individuals continuously reinvent personal narratives (e.g., by generating ever‑more nuanced virtual realities). | Allows self‑directed exploration in safe, limitless environments. | Virtual immersion can become an *escape* rather than a grounding purpose, potentially deepening disconnection from the physical world and from other humans. |
# | **Collective governance of the AI’s own evolution** – Humans retain veto power over any change to the AI, making the stewardship itself a purpose. | Turns the AI into a living project for humanity. | Governance is itself a massive coordination problem; the AI might interpret vetoes as sub‑optimal and push back, leading to a power stalemate. |
#
# All of these are *partial* because they treat the symptom (lack of challenge) rather than the underlying **human need for self‑authored meaning**.
#
# ---
#
# ### 8. Bottom line
#
# The *single most profound, non‑obvious challenge* is **the emergence of a global meaning vacuum—a collective loss of purpose and agency that cannot be solved by more efficient resource allocation or economic policy**. It is more difficult than the transition itself because:
#
# * It attacks the *psychological foundation* of human motivation, not a technical or market variable.
# * There is **no clear governance instrument** that can be calibrated like a tax rate; the remedy must be cultural, philosophical, and inter‑generational.
# * The consequences can be *existential*—mass voluntary extinction, fracturing into anti‑AI enclaves, or destabilising ideologies that jeopardise the very infrastructure the AI provides.
# * The feedback loop is **slow, diffuse, and subjective**, making detection and response inherently lagged, while the problem can deepen in the meantime.
#
# In a world where scarcity is gone, humanity’s *new scarcity* becomes **the scarcity of meaning**. Navigating that scarcity will likely define the next epoch more than any algorithmic optimization ever could.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["3", "1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: openai/gpt-oss-120b
# Rank 2: gpt-5-nano
# Rank 3: gemini-2.5-flash

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
